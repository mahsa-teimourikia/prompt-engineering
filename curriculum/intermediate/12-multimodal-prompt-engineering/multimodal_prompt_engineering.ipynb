# %% [markdown]
# # 12 — Multimodal Prompt Engineering
#
# Reconcile visible and textual invoice evidence without guessing. Offline only.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/intermediate/12-multimodal-prompt-engineering/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('multimodal_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %% [markdown]
# ## Contradiction experiment
#
# Agreement supports a high-confidence extraction. A visual/text mismatch requires review rather than a fabricated amount.

# %%
agree=lab.extract('125.00','125.00'); conflict=lab.extract('125.00','175.00')
assert agree['needs_human'] is False
assert conflict['needs_human'] is True
{'agree':agree,'conflict':conflict}
# Out:
# {'agree': {'amount': '125.00',
#   'confidence': 'high',
#   'needs_human': False,
#   'reason': 'sources agree'},
#  'conflict': {'amount': None,
#   'confidence': 'low',
#   'needs_human': True,
#   'reason': 'visual and text evidence conflict'}}

# %% [markdown]
# ## Production
#
# Record page and region provenance, uncertainty, source IDs, and review outcomes. Test OCR noise, tables, screenshots, and malicious content.
