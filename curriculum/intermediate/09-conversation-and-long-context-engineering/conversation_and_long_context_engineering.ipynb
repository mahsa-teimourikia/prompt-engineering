# %% [markdown]
# # 09 — Conversation and Long-Context Engineering
#
# Compare full history, a sliding window, summary, and retrieval on the same customer-success conversation. Offline only.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/intermediate/09-conversation-and-long-context-engineering/lab.py'
if not p.exists(): p=Path.cwd()/'lab.py'
s=spec_from_file_location('conversation_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %% [markdown]
# ## Experiment
#
# A window is cheap but loses the email preference; summary and retrieval preserve both facts in this controlled case. Test the same question before choosing a strategy.

# %%
results={x:lab.context(x) for x in ('full','window','summary','retrieval')}
assert not results['window']['retains_preference']
results
# Out:
# {'full': {'strategy': 'full',
#   'selected': ('User prefers email updates.',
#    'Order 42 is delayed.',
#    'Unrelated product discussion.',
#    'Please summarize my order status.'),
#   'tokens': 16,
#   'retains_order': True,
#   'retains_preference': True},
#  'window': {'strategy': 'window',
#   'selected': ('Unrelated product discussion.',
#    'Please summarize my order status.'),
#   'tokens': 8,
#   'retains_order': False,
#   'retains_preference': False},
#  'summary': {'strategy': 'summary',
#   'selected': ('preference=email; order=42 delayed',
#    'Please summarize my order status.'),
#   'tokens': 8,
#   'retains_order': True,
#   'retains_preference': True},
#  'retrieval': {'strategy': 'retrieval',
#   'selected': ('User prefers email updates.',
#    'Order 42 is delayed.',
#    'Please summarize my order status.'),
#   'tokens': 13,
#   'retains_order': True,
#   'retains_preference': True}}

# %% [markdown]
# ## Production and exercises
#
# Measure staleness, retention, cost, and privacy by slice. Add a conflicting preference and define which deterministic state source wins; then add a topic switch and choose a safe reset policy.
