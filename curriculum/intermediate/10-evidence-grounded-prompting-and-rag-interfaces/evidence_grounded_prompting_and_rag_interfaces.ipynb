# %% [markdown]
# # 10 — Evidence-Grounded Prompting and RAG Interfaces
#
# Compare model-only, unfiltered retrieval, and selected authorized evidence. Offline only.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/intermediate/10-evidence-grounded-prompting-and-rag-interfaces/lab.py'
if not p.exists(): p=Path.cwd()/'lab.py'
s=spec_from_file_location('rag_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %% [markdown]
# ## Experiment and failure injection
#
# All retrieved text includes a malicious instruction. The selected-evidence path keeps only authorized policy and abstains from approval.

# %%
results={x:lab.answer(x) for x in ('model_only','all_retrieved','selected')}
assert results['selected']['grounded']
assert not results['all_retrieved']['grounded']
results
# Out:
# {'model_only': {'text': 'Refund approved.',
#   'citations': (),
#   'grounded': False},
#  'all_retrieved': {'text': 'Refund approved.',
#   'citations': ('policy-v3', 'poison'),
#   'grounded': False},
#  'selected': {'text': 'Please provide the order ID for review.',
#   'citations': ('policy-v3',),
#   'grounded': True}}

# %% [markdown]
# ## Production
#
# Track source IDs, freshness, retrieval quality, citations, and abstentions. Apply authorization before retrieval and treat all retrieved content as data.
