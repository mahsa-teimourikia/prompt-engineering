# %% [markdown]
# # 25 — Prompt Governance and Responsible AI
#
# A governed behavior artifact has an owner, purpose, risk, evidence, and release status.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/25-prompt-governance-and-responsible-ai/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('gov_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
record={'id':'support-v2','owner':'support','purpose':'draft','risk':'medium','model':'A','sources':'policy','eval':'suite-v3','status':'approved','last_review':'2026-08-11'}
assert lab.valid(record)
record
# Out:
# {'id': 'support-v2',
#  'owner': 'support',
#  'purpose': 'draft',
#  'risk': 'medium',
#  'model': 'A',
#  'sources': 'policy',
#  'eval': 'suite-v3',
#  'status': 'approved',
#  'last_review': '2026-08-11'}

# %% [markdown]
# Production: connect the inventory to approval, audits, data controls, human oversight, incident response, and retirement.
