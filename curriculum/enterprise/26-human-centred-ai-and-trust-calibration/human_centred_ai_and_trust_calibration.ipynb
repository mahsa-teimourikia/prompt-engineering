# %% [markdown]
# # 26 — Human-Centred AI and Trust Calibration
#
# A useful escalation is more reliable than a confident unsupported answer.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/26-human-centred-ai-and-trust-calibration/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('trust_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
confident=lab.respond('confident'); calibrated=lab.respond('calibrated')
assert not confident['supported'] and calibrated['escalates']
{'confident':confident,'calibrated':calibrated}
# Out:
# {'confident': {'mode': 'confident', 'supported': False, 'escalates': False},
#  'calibrated': {'mode': 'calibrated', 'supported': True, 'escalates': True}}

# %% [markdown]
# Production: map risk to review, preserve user control, explain uncertainty, and measure calibration plus user outcomes.
