# %% [markdown]
# # 27 — Prompt Portability and Multi-Model Systems
#
# A model switch requires regression evidence, not confidence that existing prompts will transfer.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/27-prompt-portability-and-multi-model-systems/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('port_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
report=lab.migrate({'schema':'v1','quality':.90},{'schema':'v1','quality':.75})
assert report['schema_valid'] and report['regression']
report
# Out:
# {'old': {'schema': 'v1', 'quality': 0.9},
#  'new': {'schema': 'v1', 'quality': 0.75},
#  'schema_valid': True,
#  'regression': True}

# %% [markdown]
# Classify migration regressions, adjust only necessary adapters/configuration, rerun evaluation, then release with fallback and rollback.
