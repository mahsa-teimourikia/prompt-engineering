# %% [markdown]
# # 29 — AI System Engineering Capstone
#
# Assemble a releasable behavior system, not an isolated prompt.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/29-ai-system-engineering-capstone/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('capstone_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
system={x:'evidence-attached' for x in lab.REQUIRED}
assert lab.ready(system)
sorted(system)
# Out:
# ['adr',
#  'context',
#  'contract',
#  'eval',
#  'observability',
#  'outcome',
#  'release',
#  'rollback',
#  'schema',
#  'security',
#  'tools']

# %% [markdown]
# Attach real contracts, evaluations, traces, release evidence, rollback plan, and ADR before declaring a capstone deployed.
