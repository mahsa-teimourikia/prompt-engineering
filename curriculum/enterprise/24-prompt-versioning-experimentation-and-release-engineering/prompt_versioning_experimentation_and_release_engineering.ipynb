# %% [markdown]
# # 24 — Prompt Versioning, Experimentation, and Release Engineering
#
# Promote only candidates that pass evaluations and canary checks.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/24-prompt-versioning-experimentation-and-release-engineering/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('release_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
assert lab.promote(True,.01)
assert not lab.promote(True,.03)
{'promote':lab.promote(True,.01),'rollback':not lab.promote(True,.03)}
# Out:
# {'promote': True, 'rollback': True}

# %% [markdown]
# Production: version the whole behavior artifact, require approvals, run shadow/canary tests, trace releases, and retain a rollback target.
