# %% [markdown]
# # 28 — Prompt Architecture Patterns and System Selection
#
# Choose the simplest system that satisfies the requirements.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/28-prompt-architecture-patterns-and-system-selection/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('arch_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
scenarios={'calculation':{'deterministic':True,'evidence':False,'action':False},'policy_qa':{'deterministic':False,'evidence':True,'action':False},'operations':{'deterministic':False,'evidence':True,'action':True}}
selected={k:lab.choose(v) for k,v in scenarios.items()}
selected
# Out:
# {'calculation': 'deterministic software',
#  'policy_qa': 'retrieval-grounded generation',
#  'operations': 'tool-using workflow'}

# %% [markdown]
# Write an ADR that compares reliability, cost, latency, security, observability, and evaluation difficulty for alternatives.
