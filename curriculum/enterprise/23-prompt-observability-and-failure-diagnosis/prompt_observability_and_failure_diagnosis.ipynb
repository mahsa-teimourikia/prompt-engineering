# %% [markdown]
# # 23 — Prompt Observability and Failure Diagnosis
#
# Why did behavior change? Compare versioned traces, not anecdotes.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/23-prompt-observability-and-failure-diagnosis/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('obs_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
assert lab.diagnose(lab.TRACES[1])=='stale context'
[(t,lab.diagnose(t)) for t in lab.TRACES]
# Out:
# [({'version': 'v1', 'model': 'A', 'context': 'fresh', 'valid': True},
#   'no regression'),
#  ({'version': 'v2', 'model': 'A', 'context': 'stale', 'valid': False},
#   'stale context')]

# %% [markdown]
# Record safe identifiers for prompt, model, context, tools, validation, tokens, latency, and cost; protect sensitive data.
