# %% [markdown]
# # 22 — PromptOps
#
# Release a complete behavior artifact only after its evaluation gate passes.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/enterprise/22-promptops/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('ops_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
assert not lab.release(lab.ARTIFACT,.80)
assert lab.release(lab.ARTIFACT,.90)
{'rejected':lab.release(lab.ARTIFACT,.80),'promoted':lab.release(lab.ARTIFACT,.90)}
# Out:
# {'rejected': False, 'promoted': True}

# %% [markdown]
# Production: attach artifact version, trace IDs, release gate evidence, rollout, owner, and rollback target.
