# %% [markdown]
# # 16 — Evaluation-Driven Prompt Optimization
#
# Change one meaningful variable, then use held-out quality and safety gates.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/advanced/16-evaluation-driven-prompt-optimization/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('opt_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %% [markdown]
# ## Candidate comparison
#
# A candidate with better local quality but lower safety is rejected.

# %%
decisions={x[0]:lab.accept(x) for x in lab.RUNS}
assert decisions['add_boundary_example'] is False
assert decisions['change_schema'] is True
decisions
# Out:
# {'baseline': False, 'add_boundary_example': False, 'change_schema': True}

# %% [markdown]
# ## Production
#
# Record the hypothesis, changed component, slices, rollout, and rollback. Do not fix missing evidence by rewriting wording.
