# %% [markdown]
# # 17 — Automatic Prompt Optimization and DSPy
#
# Development improvement is not sufficient; evaluate candidates on held-out cases.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/advanced/17-automatic-prompt-optimization-and-dspy/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('dspy_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
scores={p:{split:lab.score(p,split) for split in ('dev','heldout')} for p in ('manual','optimized')}
assert scores['optimized']['dev']>scores['manual']['dev']
assert scores['optimized']['heldout']<scores['manual']['heldout']
scores
# Out:
# {'manual': {'dev': 0.7, 'heldout': 0.72},
#  'optimized': {'dev': 0.92, 'heldout': 0.65}}

# %% [markdown]
# Reject this optimized candidate: it overfits development data. Track objective, examples, cost, leakage controls, and portability.
