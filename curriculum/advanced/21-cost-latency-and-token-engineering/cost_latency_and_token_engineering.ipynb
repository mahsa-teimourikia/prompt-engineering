# %% [markdown]
# # 21 — Cost, Latency, and Token Engineering
#
# Optimize quality, cost, and latency together.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/advanced/21-cost-latency-and-token-engineering/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('cost_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
choices=[x for x in lab.OPTIONS if lab.acceptable(x)]
assert all(x['name']!='cheap' for x in choices)
choices
# Out:
# [{'name': 'full', 'quality': 0.92, 'cost': 0.04, 'latency': 900},
#  {'name': 'pruned', 'quality': 0.9, 'cost': 0.02, 'latency': 500}]

# %% [markdown]
# The cheap option is rejected because it regresses quality. Add provider token telemetry and held-out evaluation before shipping a cache or routing policy.
