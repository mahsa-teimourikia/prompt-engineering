# %% [markdown]
# # 18 — Agent and Multi-Agent Prompt Contracts
#
# Compare the least-autonomous workflow with a bounded supervisor/specialist system.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/advanced/18-agent-and-multi-agent-prompt-contracts/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('agent_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
a,b=lab.workflow(),lab.supervisor()
assert lab.evaluate(a)['bounded'] and lab.evaluate(b)['bounded']
{'workflow':lab.evaluate(a),'supervisor':lab.evaluate(b)}
# Out:
# {'workflow': {'success': True,
#   'tool_calls': 1,
#   'bounded': True,
#   'trajectory': ('classify', 'retrieve', 'draft')},
#  'supervisor': {'success': True,
#   'tool_calls': 2,
#   'bounded': True,
#   'trajectory': ('supervisor', 'researcher', 'reviewer', 'handoff')}}

# %% [markdown]
# Only choose the supervisor architecture if held-out trajectory metrics justify its added tool calls, cost, and failure modes.
