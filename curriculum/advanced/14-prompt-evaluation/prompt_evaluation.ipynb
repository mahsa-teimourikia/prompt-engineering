# %% [markdown]
# # 14 — Prompt Evaluation
#
# Compare a baseline and candidate on identical frozen cases, then inspect failure slices.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/advanced/14-prompt-evaluation/lab.py'
if not p.exists(): p=Path.cwd()/'lab.py'
s=spec_from_file_location('eval_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %% [markdown]
# ## Experiment
#
# The baseline fails the ambiguous slice; the candidate is accepted only because it improves that declared failure without regressing the held-out suite.

# %%
baseline=lab.evaluate('baseline');candidate=lab.evaluate('safe')
assert lab.metrics(candidate)['accuracy']>lab.metrics(baseline)['accuracy']
{'baseline':lab.metrics(baseline),'candidate':lab.metrics(candidate)}
# Out:
# {'baseline': {'accuracy': 0.6666666666666666, 'failures': ['ambiguous']},
#  'candidate': {'accuracy': 1.0, 'failures': []}}

# %% [markdown]
# ## Production
#
# Add human review, judges, regression gates, adversarial data, and release rollback. Never optimize prompts against a single appealing response.
