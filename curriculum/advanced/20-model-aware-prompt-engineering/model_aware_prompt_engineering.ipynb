# %% [markdown]
# # 20 — Model-Aware Prompt Engineering
#
# A portable contract stays stable while adapter-specific tuning remains isolated.

# %%
from importlib.util import module_from_spec,spec_from_file_location
from pathlib import Path
import sys
p=Path.cwd()/'curriculum/advanced/20-model-aware-prompt-engineering/lab.py'
if not p.exists():p=Path.cwd()/'lab.py'
s=spec_from_file_location('model_lab',p);lab=module_from_spec(s);sys.modules[s.name]=lab;s.loader.exec_module(lab)

# %%
runs=[lab.run(x) for x in ('A','B')]
assert all(x['contract_valid'] for x in runs)
runs
# Out:
# [{'model': 'A', 'contract_valid': True, 'latency_ms': 120, 'cost': 0.02},
#  {'model': 'B', 'contract_valid': True, 'latency_ms': 80, 'cost': 0.01}]

# %% [markdown]
# Use a regression suite before migration; choose trade-offs by measured quality, safety, cost, and latency.
